# %%
# !pip install pycaret

# %%
pip install --pre pycaret
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
from pycaret.classification import * 
import pandas as pd

# %%
# abrir o dataset
dataset = pd.read_csv('/home/vinicius/UFERSA/cilab/euthyroid_sick_syndrome/euthyroid_sick_syndrome/datasets/euthyroid/euthyroid_final_features.csv')

# %%
dataset = dataset[['classification', 'T3', 'TT4', 'T4U', 'FTI']]

# %%
dataset.head()
# Out:
#    classification   T3    TT4   T4U    FTI
# 0               1  1.0   82.0  0.73  112.0
# 1               1  1.0  101.0  0.82  123.0
# 2               1  0.8   76.0  0.77   99.0
# 3               1  0.3   87.0  0.95   91.0
# 4               1  0.8  105.0  0.88  120.0

# %%
print(dataset['classification'].value_counts()) #1 = sick, 0 = normal
# Out:
# 0    2870
# 1     292
# Name: classification, dtype: int64

# %%
# balancear os dados
from imblearn.over_sampling import SMOTE

sm = SMOTE(random_state=42, k_neighbors=5)
dataset_balanced, output_classe = sm.fit_resample(dataset[['T3', 'TT4', 'T4U', 'FTI']], dataset['classification'])

# %%
import pandas as pd 

dataset_b= pd.DataFrame(dataset_balanced)
classes = pd.DataFrame(output_classe)

# %%
final_dataset = pd.concat([dataset_b, classes], axis=1)

# %%
final_dataset.head()
# Out:
#     T3    TT4   T4U    FTI  classification
# 0  1.0   82.0  0.73  112.0               1
# 1  1.0  101.0  0.82  123.0               1
# 2  0.8   76.0  0.77   99.0               1
# 3  0.3   87.0  0.95   91.0               1
# 4  0.8  105.0  0.88  120.0               1

# %%
train_size = 0.8
session = setup(data=final_dataset, target='classification', train_size=train_size, data_split_shuffle=True, normalize = True)
# Out:
# <style type="text/css">
# #T_4f366_row8_col1, #T_4f366_row12_col1 {
#   background-color: lightgreen;
# }
# </style>
# <table id="T_4f366">
#   <thead>
#     <tr>
#       <th class="blank level0" >&nbsp;</th>
#       <th id="T_4f366_level0_col0" class="col_heading level0 col0" >Description</th>
#       <th id="T_4f366_level0_col1" class="col_heading level0 col1" >Value</th>
#     </tr>
#   </thead>
#   <tbody>
#     <tr>
#       <th id="T_4f366_level0_row0" class="row_heading level0 row0" >0</th>
#       <td id="T_4f366_row0_col0" class="data row0 col0" >Session id</td>
#       <td id="T_4f366_row0_col1" class="data row0 col1" >6955</td>
#     </tr>
#     <tr>
#       <th id="T_4f366_level0_row1" class="row_heading level0 row1" >1</th>
#       <td id="T_4f366_row1_col0" class="data row1 col0" >Target</td>
#       <td id="T_4f366_row1_col1" class="data row1 col1" >classification</td>
#     </tr>
#     <tr>
#       <th id="T_4f366_level0_row2" class="row_heading level0 row2" >2</th>
# ...

# %%
best_model = compare_models()
# Out:
#
#
# Initiated  . . . . . . . . . . . . . . . . . .              11:10:02
# Status     . . . . . . . . . . . . . . . . . .  Loading Dependencies
# Estimator  . . . . . . . . . . . . . . . . . .     Compiling Library
# <style type="text/css">
# #T_b0544 th {
#   text-align: left;
# }
# ...

# %%
print(best_model)
# Out:
# ExtraTreesClassifier(bootstrap=False, ccp_alpha=0.0, class_weight=None,
#                      criterion='gini', max_depth=None, max_features='sqrt',
#                      max_leaf_nodes=None, max_samples=None,
#                      min_impurity_decrease=0.0, min_samples_leaf=1,
#                      min_samples_split=2, min_weight_fraction_leaf=0.0,
#                      n_estimators=100, n_jobs=-1, oob_score=False,
#                      random_state=6955, verbose=0, warm_start=False)
