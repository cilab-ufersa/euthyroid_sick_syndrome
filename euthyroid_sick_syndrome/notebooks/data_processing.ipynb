# %%
import pandas as pd #importação da biblioteca pandas

# Leitura dos dados
df = pd.read_csv('..\datasets\euthyroid\euthyroid.data')
#Exibir os dados
df.head()
# Out:
#    sick-euthyroid  72  M  f f.1 f.2 f.3 f.4 f.5 f.6  ...  y     1 y.1   83  \
# 0  sick-euthyroid  45  F  f   f   f   f   f   f   f  ...  y     1   y   82
# 1  sick-euthyroid  64  F  f   f   f   f   f   f   f  ...  y     1   y  101
# 2  sick-euthyroid  56  M  f   f   f   f   f   f   f  ...  y  0.80   y   76
# 3  sick-euthyroid  78  F  t   f   f   f   t   f   f  ...  y  0.30   y   87
# 4  sick-euthyroid  80  M  f   f   f   f   f   f   f  ...  y  0.80   y  105
#
#   y.2  0.95 y.3   87 n.1 ?.1
# 0   y  0.73   y  112   n   ?
# 1   y  0.82   y  123   n   ?
# 2   y  0.77   y   99   n   ?
# 3   y  0.95   y   91   n   ?
# 4   y  0.88   y  120   n   ?
#
# [5 rows x 26 columns]
