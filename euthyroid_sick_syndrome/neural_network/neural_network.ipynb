# %%
import sys
sys.path.append('euthyroid_sick_syndrome')
import tensorflow as tf
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
from sklearn.preprocessing import StandardScaler
from utils import *
import os

# %%
#carregando o dataset e utilizando as 8 features retornadas pelo RFE

dataset = pd.read_csv('../euthyroid_sick_syndrome/datasets/euthyroid/euthyroid_final_features.csv')

# %%
output_label_dataset = dataset['classification']  #1 = sick, 0 = normal
dataset = dataset[['age', 'on_thyroxine', 'query_hypothyroid', 'TSH', 'T3', 'TT4', 'T4U','FTI']]

#dataset = dataset[ ['age', 'sex', 'on_thyroxine', 'query_hypothyroid', 'query_hyperthyroid','TSH', 'T3', 'TT4', 'T4U', 'FTI']]

#dataset = dataset[ ['age', 'sex', 'on_thyroxine', 'query_on_thyroxine', 'query_hypothyroid', 'query_hyperthyroid', 'goitre', 'TSH', 'T3', 'TT4', 'T4U', 'FTI']]

#dataset = dataset[['age', 'on_thyroxine', 'on_antithyroid_medication', 'tumor', 'goitre','T3', 'TT4', 'T4U']]

#dataset = dataset[['age', 'sex', 'query_on_thyroxine', 'on_antithyroid_medication', 'sick','tumor', 'T3', 'T4U']]

# %%
dataset.head()
# Out:
#    age  on_thyroxine  query_hypothyroid   TSH   T3    TT4   T4U    FTI
# 0   45             0                  0  1.90  1.0   82.0  0.73  112.0
# 1   64             0                  0  0.09  1.0  101.0  0.82  123.0
# 2   56             0                  0  0.00  0.8   76.0  0.77   99.0
# 3   78             1                  1  2.60  0.3   87.0  0.95   91.0
# 4   80             0                  0  1.40  0.8  105.0  0.88  120.0

# %%
#fazendo o balanceamento dos dados
dataset_res, ouput_label = balance_dataset_smote(dataset, output_label_dataset, random_state=42, k_neighbors=5)

# %%
 # Dividindo os dados em treino e teste em 80% e 20% respectivamente
input_train, input_test, output_train, output_test = slipt_and_standardize_dataset(dataset=dataset_res, output_label=ouput_label, test_size=0.1)

# %%
input_train = np.asarray( input_train)
input_test = np.asarray( input_test)
output_train =np.asarray( output_train)
output_test =np.asarray( output_test)

# %%
# Modelo de rede perceptron multicamadas com uma camada oculta de 64 neurônios
# e camada de saída com 1 neurônios (1 classes)
model = tf.keras.models.Sequential()
model.add(tf.keras.layers.Dense(64, input_dim=dataset.shape[1], activation='relu', kernel_initializer='random_uniform'))
model.add(tf.keras.layers.Dense(32, activation='relu', kernel_initializer='random_uniform'))
model.add(tf.keras.layers.Dense(1, activation='sigmoid', kernel_initializer='random_uniform'))
model.summary() #visualizando o modelo
# Out:
# Model: "sequential_8"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  dense_24 (Dense)            (None, 64)                576
#
#  dense_25 (Dense)            (None, 32)                2080
#
#  dense_26 (Dense)            (None, 1)                 33
#
# =================================================================
# Total params: 2,689
# Trainable params: 2,689
# Non-trainable params: 0
# _________________________________________________________________

# %%
# Compile model
# Otimizador Adam com taxa de aprendizado de 0.01
opt = tf.keras.optimizers.Adam()

model.compile(loss='binary_crossentropy', optimizer=opt, metrics=['accuracy'])

# callback para salvar o modelo com menor perda no conjunto de validação
checkpoint_filepath = fname = os.path.sep.join(["euthyroid_sick_syndrome", "checkpoints"
	"weights-{epoch:03d}-{val_loss:.4f}.hdf5"])
model_checkpoint_callback = tf.keras.callbacks.ModelCheckpoint( filepath=checkpoint_filepath, save_weights_only=True, monitor='val_loss', mode='min', save_best_only=True)
# early_stopping_loss
early_stopping_loss = tf.keras.callbacks.EarlyStopping(monitor='val_loss', mode='min', verbose=1, patience=10, min_delta=0.0001)

# Treinamento do modelo 
history = model.fit(input_train, output_train, epochs=200, batch_size=128, validation_split=0.2, callbacks=[model_checkpoint_callback, early_stopping_loss], use_multiprocessing=True)
# Out:
# Epoch 1/200
# 33/33 [==============================] - 1s 7ms/step - loss: 0.6799 - accuracy: 0.7972 - val_loss: 0.6428 - val_accuracy: 0.8453
# Epoch 2/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.5423 - accuracy: 0.8478 - val_loss: 0.4120 - val_accuracy: 0.8472
# Epoch 3/200
# 33/33 [==============================] - 0s 5ms/step - loss: 0.3449 - accuracy: 0.8705 - val_loss: 0.2864 - val_accuracy: 0.8917
# Epoch 4/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.2579 - accuracy: 0.9042 - val_loss: 0.2360 - val_accuracy: 0.9226
# Epoch 5/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.2157 - accuracy: 0.9218 - val_loss: 0.2207 - val_accuracy: 0.9246
# Epoch 6/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1993 - accuracy: 0.9293 - val_loss: 0.2141 - val_accuracy: 0.9236
# Epoch 7/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1924 - accuracy: 0.9313 - val_loss: 0.2112 - val_accuracy: 0.9255
# Epoch 8/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1859 - accuracy: 0.9334 - val_loss: 0.2071 - val_accuracy: 0.9275
# Epoch 9/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1812 - accuracy: 0.9364 - val_loss: 0.2024 - val_accuracy: 0.9323
# Epoch 10/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1775 - accuracy: 0.9361 - val_loss: 0.2000 - val_accuracy: 0.9323
# Epoch 11/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1749 - accuracy: 0.9368 - val_loss: 0.1964 - val_accuracy: 0.9342
# Epoch 12/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1705 - accuracy: 0.9407 - val_loss: 0.1995 - val_accuracy: 0.9294
# Epoch 13/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1679 - accuracy: 0.9412 - val_loss: 0.1931 - val_accuracy: 0.9323
# Epoch 14/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1644 - accuracy: 0.9409 - val_loss: 0.1901 - val_accuracy: 0.9323
# Epoch 15/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1609 - accuracy: 0.9414 - val_loss: 0.1884 - val_accuracy: 0.9371
# Epoch 16/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1600 - accuracy: 0.9426 - val_loss: 0.1858 - val_accuracy: 0.9333
# Epoch 17/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1556 - accuracy: 0.9426 - val_loss: 0.1843 - val_accuracy: 0.9323
# Epoch 18/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1537 - accuracy: 0.9434 - val_loss: 0.1809 - val_accuracy: 0.9333
# Epoch 19/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1522 - accuracy: 0.9434 - val_loss: 0.1797 - val_accuracy: 0.9323
# Epoch 20/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1491 - accuracy: 0.9441 - val_loss: 0.1798 - val_accuracy: 0.9323
# Epoch 21/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1478 - accuracy: 0.9443 - val_loss: 0.1752 - val_accuracy: 0.9342
# Epoch 22/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1452 - accuracy: 0.9439 - val_loss: 0.1735 - val_accuracy: 0.9333
# Epoch 23/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1428 - accuracy: 0.9458 - val_loss: 0.1722 - val_accuracy: 0.9313
# Epoch 24/200
# 33/33 [==============================] - 0s 4ms/step - loss: 0.1413 - accuracy: 0.9453 - val_loss: 0.1696 - val_accuracy: 0.9342
# Epoch 25/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1388 - accuracy: 0.9463 - val_loss: 0.1683 - val_accuracy: 0.9333
# Epoch 26/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1366 - accuracy: 0.9477 - val_loss: 0.1675 - val_accuracy: 0.9313
# Epoch 27/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1350 - accuracy: 0.9492 - val_loss: 0.1660 - val_accuracy: 0.9381
# Epoch 28/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1344 - accuracy: 0.9489 - val_loss: 0.1627 - val_accuracy: 0.9391
# Epoch 29/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1319 - accuracy: 0.9506 - val_loss: 0.1622 - val_accuracy: 0.9391
# Epoch 30/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1320 - accuracy: 0.9523 - val_loss: 0.1643 - val_accuracy: 0.9313
# Epoch 31/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1289 - accuracy: 0.9526 - val_loss: 0.1632 - val_accuracy: 0.9333
# Epoch 32/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1272 - accuracy: 0.9528 - val_loss: 0.1585 - val_accuracy: 0.9362
# Epoch 33/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.9540 - val_loss: 0.1596 - val_accuracy: 0.9352
# Epoch 34/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1263 - accuracy: 0.9523 - val_loss: 0.1565 - val_accuracy: 0.9371
# Epoch 35/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1241 - accuracy: 0.9562 - val_loss: 0.1574 - val_accuracy: 0.9381
# Epoch 36/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1219 - accuracy: 0.9555 - val_loss: 0.1545 - val_accuracy: 0.9371
# Epoch 37/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9550 - val_loss: 0.1514 - val_accuracy: 0.9429
# Epoch 38/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1208 - accuracy: 0.9562 - val_loss: 0.1506 - val_accuracy: 0.9420
# Epoch 39/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1185 - accuracy: 0.9560 - val_loss: 0.1502 - val_accuracy: 0.9449
# Epoch 40/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1166 - accuracy: 0.9572 - val_loss: 0.1483 - val_accuracy: 0.9429
# Epoch 41/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1156 - accuracy: 0.9574 - val_loss: 0.1485 - val_accuracy: 0.9449
# Epoch 42/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1146 - accuracy: 0.9560 - val_loss: 0.1468 - val_accuracy: 0.9507
# Epoch 43/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1126 - accuracy: 0.9593 - val_loss: 0.1498 - val_accuracy: 0.9439
# Epoch 44/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1133 - accuracy: 0.9591 - val_loss: 0.1465 - val_accuracy: 0.9478
# Epoch 45/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1120 - accuracy: 0.9586 - val_loss: 0.1445 - val_accuracy: 0.9478
# Epoch 46/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1101 - accuracy: 0.9596 - val_loss: 0.1423 - val_accuracy: 0.9545
# Epoch 47/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1090 - accuracy: 0.9615 - val_loss: 0.1409 - val_accuracy: 0.9478
# Epoch 48/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1087 - accuracy: 0.9620 - val_loss: 0.1404 - val_accuracy: 0.9497
# Epoch 49/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1062 - accuracy: 0.9637 - val_loss: 0.1404 - val_accuracy: 0.9536
# Epoch 50/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1076 - accuracy: 0.9630 - val_loss: 0.1388 - val_accuracy: 0.9497
# Epoch 51/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1050 - accuracy: 0.9610 - val_loss: 0.1374 - val_accuracy: 0.9555
# Epoch 52/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1029 - accuracy: 0.9627 - val_loss: 0.1404 - val_accuracy: 0.9545
# Epoch 53/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1039 - accuracy: 0.9610 - val_loss: 0.1386 - val_accuracy: 0.9565
# Epoch 54/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.1022 - accuracy: 0.9642 - val_loss: 0.1361 - val_accuracy: 0.9574
# Epoch 55/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.1004 - accuracy: 0.9642 - val_loss: 0.1343 - val_accuracy: 0.9536
# Epoch 56/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0996 - accuracy: 0.9664 - val_loss: 0.1344 - val_accuracy: 0.9545
# Epoch 57/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0987 - accuracy: 0.9654 - val_loss: 0.1354 - val_accuracy: 0.9555
# Epoch 58/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0985 - accuracy: 0.9656 - val_loss: 0.1324 - val_accuracy: 0.9555
# Epoch 59/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0976 - accuracy: 0.9652 - val_loss: 0.1341 - val_accuracy: 0.9584
# Epoch 60/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0981 - accuracy: 0.9654 - val_loss: 0.1339 - val_accuracy: 0.9584
# Epoch 61/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0970 - accuracy: 0.9654 - val_loss: 0.1329 - val_accuracy: 0.9594
# Epoch 62/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0955 - accuracy: 0.9685 - val_loss: 0.1342 - val_accuracy: 0.9584
# Epoch 63/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0948 - accuracy: 0.9666 - val_loss: 0.1316 - val_accuracy: 0.9565
# Epoch 64/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0941 - accuracy: 0.9678 - val_loss: 0.1337 - val_accuracy: 0.9574
# Epoch 65/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0943 - accuracy: 0.9700 - val_loss: 0.1304 - val_accuracy: 0.9584
# Epoch 66/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0913 - accuracy: 0.9712 - val_loss: 0.1308 - val_accuracy: 0.9584
# Epoch 67/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0911 - accuracy: 0.9697 - val_loss: 0.1318 - val_accuracy: 0.9584
# Epoch 68/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0919 - accuracy: 0.9697 - val_loss: 0.1311 - val_accuracy: 0.9574
# Epoch 69/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0897 - accuracy: 0.9714 - val_loss: 0.1296 - val_accuracy: 0.9594
# Epoch 70/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0915 - accuracy: 0.9710 - val_loss: 0.1312 - val_accuracy: 0.9565
# Epoch 71/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0882 - accuracy: 0.9714 - val_loss: 0.1271 - val_accuracy: 0.9594
# Epoch 72/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0878 - accuracy: 0.9714 - val_loss: 0.1289 - val_accuracy: 0.9603
# Epoch 73/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0871 - accuracy: 0.9717 - val_loss: 0.1295 - val_accuracy: 0.9594
# Epoch 74/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0870 - accuracy: 0.9719 - val_loss: 0.1283 - val_accuracy: 0.9623
# Epoch 75/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0874 - accuracy: 0.9705 - val_loss: 0.1270 - val_accuracy: 0.9594
# Epoch 76/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0865 - accuracy: 0.9724 - val_loss: 0.1280 - val_accuracy: 0.9594
# Epoch 77/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0862 - accuracy: 0.9714 - val_loss: 0.1284 - val_accuracy: 0.9594
# Epoch 78/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0843 - accuracy: 0.9729 - val_loss: 0.1268 - val_accuracy: 0.9603
# Epoch 79/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0851 - accuracy: 0.9719 - val_loss: 0.1291 - val_accuracy: 0.9603
# Epoch 80/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0831 - accuracy: 0.9736 - val_loss: 0.1266 - val_accuracy: 0.9603
# Epoch 81/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0833 - accuracy: 0.9736 - val_loss: 0.1260 - val_accuracy: 0.9642
# Epoch 82/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0837 - accuracy: 0.9736 - val_loss: 0.1308 - val_accuracy: 0.9584
# Epoch 83/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0826 - accuracy: 0.9729 - val_loss: 0.1292 - val_accuracy: 0.9574
# Epoch 84/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0822 - accuracy: 0.9736 - val_loss: 0.1308 - val_accuracy: 0.9594
# Epoch 85/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0813 - accuracy: 0.9746 - val_loss: 0.1283 - val_accuracy: 0.9594
# Epoch 86/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0797 - accuracy: 0.9746 - val_loss: 0.1239 - val_accuracy: 0.9623
# Epoch 87/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0802 - accuracy: 0.9756 - val_loss: 0.1252 - val_accuracy: 0.9623
# Epoch 88/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0799 - accuracy: 0.9751 - val_loss: 0.1253 - val_accuracy: 0.9613
# Epoch 89/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0798 - accuracy: 0.9729 - val_loss: 0.1249 - val_accuracy: 0.9632
# Epoch 90/200
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0796 - accuracy: 0.9758 - val_loss: 0.1242 - val_accuracy: 0.9632
# Epoch 91/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0775 - accuracy: 0.9751 - val_loss: 0.1257 - val_accuracy: 0.9613
# Epoch 92/200
# 33/33 [==============================] - 0s 5ms/step - loss: 0.0773 - accuracy: 0.9756 - val_loss: 0.1275 - val_accuracy: 0.9632
# Epoch 93/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0773 - accuracy: 0.9758 - val_loss: 0.1261 - val_accuracy: 0.9632
# Epoch 94/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0775 - accuracy: 0.9746 - val_loss: 0.1231 - val_accuracy: 0.9662
# Epoch 95/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0760 - accuracy: 0.9770 - val_loss: 0.1274 - val_accuracy: 0.9632
# Epoch 96/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0780 - accuracy: 0.9758 - val_loss: 0.1230 - val_accuracy: 0.9662
# Epoch 97/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0754 - accuracy: 0.9760 - val_loss: 0.1254 - val_accuracy: 0.9642
# Epoch 98/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0745 - accuracy: 0.9758 - val_loss: 0.1228 - val_accuracy: 0.9652
# Epoch 99/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0758 - accuracy: 0.9739 - val_loss: 0.1230 - val_accuracy: 0.9623
# Epoch 100/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0756 - accuracy: 0.9756 - val_loss: 0.1207 - val_accuracy: 0.9681
# Epoch 101/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0740 - accuracy: 0.9782 - val_loss: 0.1244 - val_accuracy: 0.9642
# Epoch 102/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0743 - accuracy: 0.9775 - val_loss: 0.1346 - val_accuracy: 0.9632
# Epoch 103/200
# 33/33 [==============================] - 0s 6ms/step - loss: 0.0740 - accuracy: 0.9770 - val_loss: 0.1207 - val_accuracy: 0.9662
# Epoch 104/200
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0720 - accuracy: 0.9782 - val_loss: 0.1212 - val_accuracy: 0.9671
# Epoch 105/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0727 - accuracy: 0.9777 - val_loss: 0.1248 - val_accuracy: 0.9623
# Epoch 106/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0723 - accuracy: 0.9775 - val_loss: 0.1197 - val_accuracy: 0.9671
# Epoch 107/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0720 - accuracy: 0.9775 - val_loss: 0.1234 - val_accuracy: 0.9632
# Epoch 108/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0703 - accuracy: 0.9799 - val_loss: 0.1267 - val_accuracy: 0.9642
# Epoch 109/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0705 - accuracy: 0.9782 - val_loss: 0.1216 - val_accuracy: 0.9642
# Epoch 110/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0727 - accuracy: 0.9785 - val_loss: 0.1208 - val_accuracy: 0.9662
# Epoch 111/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0695 - accuracy: 0.9792 - val_loss: 0.1215 - val_accuracy: 0.9662
# Epoch 112/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0701 - accuracy: 0.9792 - val_loss: 0.1233 - val_accuracy: 0.9632
# Epoch 113/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0696 - accuracy: 0.9777 - val_loss: 0.1223 - val_accuracy: 0.9652
# Epoch 114/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9785 - val_loss: 0.1234 - val_accuracy: 0.9623
# Epoch 115/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0691 - accuracy: 0.9797 - val_loss: 0.1210 - val_accuracy: 0.9671
# Epoch 116/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0676 - accuracy: 0.9780 - val_loss: 0.1193 - val_accuracy: 0.9671
# Epoch 117/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0670 - accuracy: 0.9804 - val_loss: 0.1226 - val_accuracy: 0.9671
# Epoch 118/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0689 - accuracy: 0.9782 - val_loss: 0.1212 - val_accuracy: 0.9662
# Epoch 119/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0686 - accuracy: 0.9777 - val_loss: 0.1207 - val_accuracy: 0.9632
# Epoch 120/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0670 - accuracy: 0.9789 - val_loss: 0.1215 - val_accuracy: 0.9662
# Epoch 121/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0671 - accuracy: 0.9799 - val_loss: 0.1248 - val_accuracy: 0.9623
# Epoch 122/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0663 - accuracy: 0.9792 - val_loss: 0.1235 - val_accuracy: 0.9662
# Epoch 123/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0666 - accuracy: 0.9802 - val_loss: 0.1208 - val_accuracy: 0.9662
# Epoch 124/200
# 33/33 [==============================] - 0s 2ms/step - loss: 0.0660 - accuracy: 0.9806 - val_loss: 0.1242 - val_accuracy: 0.9652
# Epoch 125/200
# 33/33 [==============================] - 0s 4ms/step - loss: 0.0651 - accuracy: 0.9809 - val_loss: 0.1211 - val_accuracy: 0.9691
# Epoch 126/200
# 33/33 [==============================] - 0s 3ms/step - loss: 0.0669 - accuracy: 0.9799 - val_loss: 0.1222 - val_accuracy: 0.9652
# Epoch 126: early stopping

# %%
# Plot training & validation accuracy values
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Função Perda')
plt.ylabel('MSE')
plt.xlabel('Epocas')
plt.legend(['Treino', 'Teste'], loc='upper left')
plt.show()

# %%
output_model = model.predict(input_test)
# Out:
# 18/18 [==============================] - 0s 830us/step

# %%
accuracy(output_test, output_model.round())
precision(output_test, output_model.round())
recall(output_test, output_model.round())
f1(output_test, output_model.round())
# Out:
# A acurácia é de:  0.9860627177700348
# A precisão é de:  0.9820143884892086
# A pontuação de recall é de:  0.9891304347826086
# A pontuação de F1 é de:  0.9855595667870036

# %%
#model.save('../models/model.h5')
#history_df = pd.DataFrame(history.history)
#history_df.to_csv('history.csv', index=False)
