# %%
from utils import prepare_dataset

labels = ['classificação', 'age', 'sex', 'on_thyroxine', 'query_on_thyroxine', 'on_antithyroid_medication', 'thyroid_surgery', 'query_hypothyroid', 'query_hyperthyroid', 'pregnant', 'sick', 'tumor', 'lithium', 'goitre', 'TSH_measured', 'TSH', 'T3_measured', 'T3', 'TT4_measured', 'TT4', 'T4U_measured', 'T4U', 'FTI_measured', 'FTI', 'TBG_measured', 'TBG']
# Chamada da função prepare_dataset para preparar o dataset
prepare_dataset(path_origin='..\euthyroid_sick_syndrome\datasets\euthyroid\euthyroid.data', columns_labels=labels, path_destiny='..\euthyroid_sick_syndrome\datasets\euthyroid\euthyroid.csv')

# %%
import pandas as pd 
dataset = pd.read_csv('..\euthyroid_sick_syndrome\datasets\euthyroid\euthyroid.csv')
dataset.head()
# Out:
#     classificação age sex on_thyroxine query_on_thyroxine  \
# 0  sick-euthyroid  45   F            f                  f
# 1  sick-euthyroid  64   F            f                  f
# 2  sick-euthyroid  56   M            f                  f
# 3  sick-euthyroid  78   F            t                  f
# 4  sick-euthyroid  80   M            f                  f
#
#   on_antithyroid_medication thyroid_surgery query_hypothyroid  \
# 0                         f               f                 f
# 1                         f               f                 f
# 2                         f               f                 f
# 3                         f               f                 t
# 4                         f               f                 f
#
#   query_hyperthyroid pregnant  ... T3_measured    T3 TT4_measured  TT4  \
# 0                  f        f  ...           y     1            y   82
# 1                  f        f  ...           y     1            y  101
# ...
